# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

gujarat2017 = pd.read_csv("/content/drive/MyDrive/Wind Speed/Dwarka, Gujrat Data/2968042_22.25_68.98_2017.csv")
gujarat2018 = pd.read_csv("/content/drive/MyDrive/Wind Speed/Dwarka, Gujrat Data/2968042_22.25_68.98_2018.csv")
gujarat2019 = pd.read_csv("/content/drive/MyDrive/Wind Speed/Dwarka, Gujrat Data/2968042_22.25_68.98_2019.csv")

# %%
frames = [gujarat2017, gujarat2018, gujarat2019]
gujaratData = pd.concat(frames)

# %%
y = gujaratData["Wind Speed"]
x = gujaratData.drop(['Wind Speed'], axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=123)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import joblib

# %%
# Extra Tree
etPred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/extraTreePred.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': etPred})

color = ["violet"]
sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
# Randomised Extra Tree
etRandomPred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/extraTreeRandomizedPred.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': etRandomPred})

sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
# Random Forest
rfPred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/randomForestPred.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': rfPred})

sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
# Randomised Random Forest
rfRandomPred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/randomForestRandomizedPred.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': rfRandomPred})

sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
# LGBM
lgbmPred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/lightGBMPred.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': lgbmPred})

sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
# Randomised LGBM
lgbmRandomPred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/lightGBMRandomizedPred.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': lgbmRandomPred})

sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
# XGB
xgbPred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/xgboostPred.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': xgbPred})

sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
# Randomised XGB
xgbRandomPred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/xgboostRandomizedPred.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': xgbRandomPred})

sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
ensemblePred = np.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/stackEnsemble.npy")

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': ensemblePred})

sns.set_palette("copper_r")
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False)

d_line= np.arange(df_results.min().min(), df_results.max().max())
plt.plot(d_line, d_line, color='brown', linewidth=3)
plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
# Extra Tree

etR2 = r2_score(y_test, etPred)
etMSE = mean_squared_error(y_test, etPred)
etRMSE = np.sqrt(mean_squared_error(y_test, etPred))
etMAE = mean_absolute_error(y_test, etPred)
etMAPE = mean_absolute_percentage_error(y_test, etPred)

print(etR2, etMSE, etRMSE, etMAE, etMAPE)
# Out:
# 0.9400849608240744 0.16596194500172953 0.40738427191256354 0.275711172604635 0.07600562489185787

# %%
# Randomised Extra Tree

etRandomR2 = r2_score(y_test, etRandomPred)
etRandomMSE = mean_squared_error(y_test, etRandomPred)
etRandomRMSE = np.sqrt(mean_squared_error(y_test, etRandomPred))
etRandomMAE = mean_absolute_error(y_test, etRandomPred)
etRandomMAPE = mean_absolute_percentage_error(y_test, etRandomPred)

print(etRandomR2, etRandomMSE, etRandomRMSE, etRandomMAE, etRandomMAPE)
# Out:
# 0.940120214089314 0.16586429505361472 0.40726440435374994 0.2775138936930707 0.07668138464596871

# %%
# Random Forest

rfR2 = r2_score(y_test, rfPred)
rfMSE = mean_squared_error(y_test, rfPred)
rfRMSE = np.sqrt(mean_squared_error(y_test, rfPred))
rfMAE = mean_absolute_error(y_test, rfPred)
rfMAPE = mean_absolute_percentage_error(y_test, rfPred)

print(rfR2, rfMSE, rfRMSE, rfMAE, rfMAPE)
# Out:
# 0.9156529596567111 0.23363748172489335 0.4833606125088114 0.33960394327222415 0.09404793882622818

# %%
# Randomised Random Forest

rfRandomR2 = r2_score(y_test, rfRandomPred)
rfRandomMSE = mean_squared_error(y_test, rfRandomPred)
rfRandomRMSE = np.sqrt(mean_squared_error(y_test, rfRandomPred))
rfRandomMAE = mean_absolute_error(y_test, rfRandomPred)
rfRandomMAPE = mean_absolute_percentage_error(y_test, rfRandomPred)

print(rfRandomR2, rfRandomMSE, rfRandomRMSE, rfRandomMAE, rfRandomMAPE)
# Out:
# 0.9271669670652677 0.20174420266556503 0.44915944013853815 0.3113053574419965 0.08542002060741181

# %%
# LGBM

lgbmR2 = r2_score(y_test, lgbmPred)
lgbmMSE = mean_squared_error(y_test, lgbmPred)
lgbmRMSE = np.sqrt(mean_squared_error(y_test, lgbmPred))
lgbmMAE = mean_absolute_error(y_test, lgbmPred)
lgbmMAPE = mean_absolute_percentage_error(y_test, lgbmPred)

print(lgbmR2, lgbmMSE, lgbmRMSE, lgbmMAE, lgbmMAPE)
# Out:
# 0.8076767067409241 0.5327268121229797 0.7298813685270913 0.5635192514701892 0.14827899106857004

# %%
# Randomised LGBM


lgbmRandomR2 = r2_score(y_test, lgbmRandomPred)
lgbmRandomMSE = mean_squared_error(y_test, lgbmRandomPred)
lgbmRandomRMSE = np.sqrt(mean_squared_error(y_test, lgbmRandomPred))
lgbmRandomMAE = mean_absolute_error(y_test, lgbmRandomPred)
lgbmRandomMAPE = mean_absolute_percentage_error(y_test, lgbmRandomPred)

print(lgbmRandomR2, lgbmRandomMSE, lgbmRandomRMSE, lgbmRandomMAE, lgbmRandomMAPE)
# Out:
# 0.8110304444101593 0.5234371106679317 0.7234895373589944 0.5560643964989466 0.14569685283430905

# %%
# XGB

xgbR2 = r2_score(y_test, xgbPred)
xgbMSE = mean_squared_error(y_test, xgbPred)
xgbRMSE = np.sqrt(mean_squared_error(y_test, xgbPred))
xgbMAE = mean_absolute_error(y_test, xgbPred)
xgbMAPE = mean_absolute_percentage_error(y_test, xgbPred)

print(xgbR2, xgbMSE, xgbRMSE, xgbMAE, xgbMAPE)
# Out:
# 0.6998946742621888 0.8312781607065575 0.9117445698804888 0.7001075873047261 0.17678222947242314

# %%
# XGB Random

xgbRandomR2 = r2_score(y_test, xgbRandomPred)
xgbRandomMSE = mean_squared_error(y_test, xgbRandomPred)
xgbRandomRMSE = np.sqrt(mean_squared_error(y_test, xgbRandomPred))
xgbRandomMAE = mean_absolute_error(y_test, xgbRandomPred)
xgbRandomMAPE = mean_absolute_percentage_error(y_test, xgbRandomPred)

print(xgbRandomR2, xgbRandomMSE, xgbRandomRMSE, xgbRandomMAE, xgbRandomMAPE)
# Out:
# 0.9382782438510668 0.17096646919185052 0.4134809175667609 0.29174940687802153 0.07760892179499766

# %%
# Ensemble

ensembleR2 = r2_score(y_test, ensemblePred)
ensembleMSE = mean_squared_error(y_test, ensemblePred)
ensembleRMSE = np.sqrt(mean_squared_error(y_test, ensemblePred))
ensembleMAE = mean_absolute_error(y_test, ensemblePred)
ensembleMAPE = mean_absolute_percentage_error(y_test, ensemblePred)

print(ensembleR2, ensembleMSE, ensembleRMSE, ensembleMAE, ensembleMAPE)
# Out:
# 0.9509685776668959 0.13581481925948338 0.36853062187487673 0.2549026000230599 0.06762572326971575

# %%
r2Scores = [etR2, etRandomR2, rfR2, rfRandomR2, lgbmR2, lgbmRandomR2, xgbR2, xgbRandomR2, ensembleR2]
mseScores = [etMSE, etRandomMSE, rfMSE, rfRandomMSE, lgbmMSE, lgbmRandomMSE, xgbMSE, xgbRandomMSE, ensembleMSE]
rmseScores = [etRMSE, etRandomRMSE, rfRMSE, rfRandomRMSE, lgbmRMSE, lgbmRandomRMSE, xgbRMSE, xgbRandomRMSE, ensembleRMSE]
maeScores = [etMAE, etRandomMAE, rfMAE, rfRandomMAE, lgbmMAE, lgbmRandomMAE, xgbMAE, xgbRandomMAE, ensembleMAE]
mapeScores = [etMAPE, etRandomMAPE, rfMAPE, rfRandomMAPE, lgbmMAPE, lgbmRandomMAPE, xgbMAPE, xgbRandomMAPE, ensembleMAPE]

# algos = ["Extra Tree", "Randomized Extra Tree", "Random Forest", "Randomized Random Forest", 
#          "LightGBM", "LightGBM", "XGBoost", "Randomized XGBoost", "Stacked Model"]

# %%
names = ["R2", "MSE", "RMSE", "MAE", "MAPE"]
scores = [r2Scores, mseScores, rmseScores, maeScores, mapeScores]

# %%
fig = plt.figure()
fig.suptitle('Regression Model Comparison')
ax = fig.add_subplot(111)
plt.boxplot(scores)
ax.set_xticklabels(names)
plt.show()

# %%
# !pip install shap
import shap
shap.initjs()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 KB 9.2 MB/s eta 0:00:00
# ...

# %%
model = joblib.load("/content/drive/MyDrive/Wind Speed/gujaratFiles/extraTree.pkl")
pred = model.predict(X_test)
# Out:
# Trying to unpickle estimator ExtraTreeRegressor from version 1.1.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# Trying to unpickle estimator ExtraTreesRegressor from version 1.1.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations

# %%
r2_score(y_test, pred)
# Out:
# 0.9400849608240744

# %%
explainer = shap.TreeExplainer(model)

# %%
# Visualize one value
single_shap_value = explainer(X_test.sample(n=1))
shap.summary_plot(single_shap_value, feature_names=X_test.columns, plot_type='bar')
plt.show()

# %%
# Visualize all values
shap_values = explainer(X_test)
shap.summary_plot(shap_values, feature_names=X_test.columns)
plt.show()
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
shap.plots.heatmap(shap_values)
plt.show()

# %%
etEval = pd.read_csv("/content/drive/MyDrive/Wind Speed/gujaratEvaluation/etEvaluation.csv")
rfEval = pd.read_csv("/content/drive/MyDrive/Wind Speed/gujaratEvaluation/rfEvaluation.csv")
lgbmEval = pd.read_csv("/content/drive/MyDrive/Wind Speed/gujaratEvaluation/lgbmEvaluation.csv")
xgbEval = pd.read_csv("/content/drive/MyDrive/Wind Speed/gujaratEvaluation/xgbEvaluation.csv")

# %%
names = ["Extra Tree", "Random Forest", "LightGBM", "XGBoost"]

# %%
r2 = {"Extra Tree": etEval.loc[:,'r2'], "Random Forest": rfEval.loc[:,'r2'], "LightGBM": lgbmEval.loc[:,'r2'], "XGBoost": xgbEval.loc[:,'r2']}
mse = {"Extra Tree": etEval.loc[:,'mse'], "Random Forest": rfEval.loc[:,'mse'], "LightGBM": lgbmEval.loc[:,'mse'], "XGBoost": xgbEval.loc[:,'mse']}
rmse = {"Extra Tree": etEval.loc[:,'rmse'], "Random Forest": rfEval.loc[:,'rmse'], "LightGBM": lgbmEval.loc[:,'rmse'], "XGBoost": xgbEval.loc[:,'rmse']}
mae = {"Extra Tree": etEval.loc[:,'mae'], "Random Forest": rfEval.loc[:,'mae'], "LightGBM": lgbmEval.loc[:,'mae'], "XGBoost": xgbEval.loc[:,'mae']}
mape = {"Extra Tree": etEval.loc[:,'mape'], "Random Forest": rfEval.loc[:,'mape'], "LightGBM": lgbmEval.loc[:,'mape'], "XGBoost": xgbEval.loc[:,'mape']}
time = {"Extra Tree": etEval.loc[:,'time'], "Random Forest": rfEval.loc[:,'time'], "LightGBM": lgbmEval.loc[:,'time'], "XGBoost": xgbEval.loc[:,'time']}

# %%
fig = plt.figure()
fig.suptitle('R2 Score Comparison')
sns.boxplot(data=pd.DataFrame(r2), palette="Set1")
plt.show()

# %%
fig = plt.figure()
fig.suptitle('MSE Comparison')
sns.boxplot(data=pd.DataFrame(mse), palette="Set1")
plt.show()

# %%
fig = plt.figure()
fig.suptitle('RMSE Comparison')
sns.boxplot(data=pd.DataFrame(rmse), palette="Set1")
plt.show()

# %%
fig = plt.figure()
fig.suptitle('MAE Comparison')
sns.boxplot(data=pd.DataFrame(mae), palette="Set1")
plt.show()

# %%
fig = plt.figure()
fig.suptitle('MAPE Comparison')
sns.boxplot(data=pd.DataFrame(mape), palette="Set1")
plt.show()

# %%
fig = plt.figure()
fig.suptitle('Time Comparison')
sns.boxplot(data=pd.DataFrame(time), palette="Set1")
plt.show()
